# %%
import json

# get one row from bronze
sample = spark.table("workspace.bronze.crypto_raw").limit(1).toPandas().to_dict(orient="records")

with open("/tmp/coingecko_sample.json", "w") as f:
    json.dump(sample, f, indent=4, default=str)

print("saved!")

# %% [markdown]
# ##show sample

# %%
print(json.dumps(sample, indent=4, default=str))
